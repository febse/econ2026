# %% [markdown]
# ## Statistical Distributions
#
# - [Discrete distributions](https://www.desmos.com/calculator/8qjdx4zkhg)
# - [Continuous distributions](https://www.desmos.com/calculator/5roclvwwtd)
# - [The normal distribution](https://www.desmos.com/calculator/vnuvhbfuc5)
