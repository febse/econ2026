# %%
import pandas as pd

dt = pd.read_csv("https://github.com/febse/data/raw/refs/heads/main/econ/invoices.txt", sep="\t")
dt["Time"] = 60 * dt["Time"]
dt = dt.rename(columns={"Time": "T", "Invoices": "I"})

dt1 = dt[["I", "T"]]
