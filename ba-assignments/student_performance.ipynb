# %%
if (!require("tidyverse")) {
  install.packages("tidyverse")
}

library(tidyverse)

dt <- read_csv2("https://github.com/febse/data/raw/refs/heads/main/econ/student_performance.zip")
dt |> head()
# Out:
# ℹ Using "','" as decimal and "'.'" as grouping mark. Use `read_delim()` for more control.
#
# Rows: 145 Columns: 33
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ";"
# chr  (1): student_id
# dbl (32): age, sex, graduated_h_school_type, scholarship_type, additional_wo...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
#   student_id age sex graduated_h_school_type scholarship_type additional_work
# 1 STUDENT1   2   2   3                       3                1
# 2 STUDENT2   2   2   3                       3                1
# 3 STUDENT3   2   2   2                       3                2
# 4 STUDENT4   1   1   1                       3                1
# 5 STUDENT5   2   2   1                       3                2
# 6 STUDENT6   2   2   2                       3                2
# ...
